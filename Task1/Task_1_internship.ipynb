# %% [markdown]
# # Data analytics Internship

# %% [markdown]
# # Task 1 : Perform Data Cleaning
# - Clean a dataset by removing missing values
#  - and outliers

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %% [markdown]
# # reading csv_file

# %%
df=pd.read_csv("sample_dataset.csv")

# %%
df
# Out:
#               Segment                   Country     Product   Discount Band   \
# 0          Government                    Canada   Carretera            None
# 1                 NaN                   Germany   Carretera            None
# 2           Midmarket                    France          NaN             NaN
# 3           Midmarket                   Germany   Carretera            None
# 4           Midmarket                    Mexico   Carretera            None
# ..                ...                       ...          ...             ...
# 695    Small Business                    France          NaN           High
# 696    Small Business                    Mexico    Amarilla            High
# 697               NaN                    Mexico     Montana            High
# 698        Government                    Canada          NaN           High
# 699  Channel Partners  United States of America         VTT              NaN
#
# ...

# %% [markdown]
# # checking starting rows using head method()

# %%
df.head()
# Out:
#       Segment  Country     Product   Discount Band   Units Sold  \
# 0  Government   Canada   Carretera            None       1618.5
# 1         NaN  Germany   Carretera            None          NaN
# 2   Midmarket   France          NaN             NaN         NaN
# 3   Midmarket  Germany   Carretera            None        888.0
# 4   Midmarket   Mexico   Carretera            None       2470.0
#
#    Manufacturing Price   Sale Price   Gross Sales   Discounts         Sales   \
# 0                $3.00       $20.00    $32,370.00        $-      $32,370.00
# 1                $3.00       $20.00    $26,420.00        $-      $26,420.00
# 2                $3.00       $15.00            NaN       $-      $32,670.00
# 3                $3.00       $15.00    $13,320.00        $-      $13,320.00
# 4                $3.00       $15.00    $37,050.00        $-      $37,050.00
#
#           COGS        Profit         Date  Month Number  Month Name     Year
# ...

# %% [markdown]
# # checking last rows using tail method()

# %%
df.tail()
# Out:
#               Segment                   Country    Product   Discount Band   \
# 695    Small Business                    France         NaN           High
# 696    Small Business                    Mexico   Amarilla            High
# 697               NaN                    Mexico    Montana            High
# 698        Government                    Canada         NaN           High
# 699  Channel Partners  United States of America        VTT              NaN
#
#      Units Sold  Manufacturing Price   Sale Price     Gross Sales   \
# 695      2475.0              $260.00      $300.00    $7,42,500.00
# 696       546.0                   NaN     $300.00    $1,63,800.00
# 697      1368.0                $5.00        $7.00       $9,576.00
# 698       723.0               $10.00        $7.00       $5,061.00
# 699      1806.0              $250.00       $12.00      $21,672.00
#
#          Discounts           Sales            COGS        Profit         Date  \
# ...

# %% [markdown]
# # printing original dataframe

# %%
print("original dataframe")
df
# Out:
# original dataframe
#               Segment                   Country     Product   Discount Band   \
# 0          Government                    Canada   Carretera            None
# 1                 NaN                   Germany   Carretera            None
# 2           Midmarket                    France          NaN             NaN
# 3           Midmarket                   Germany   Carretera            None
# 4           Midmarket                    Mexico   Carretera            None
# ..                ...                       ...          ...             ...
# 695    Small Business                    France          NaN           High
# 696    Small Business                    Mexico    Amarilla            High
# 697               NaN                    Mexico     Montana            High
# 698        Government                    Canada          NaN           High
# 699  Channel Partners  United States of America         VTT              NaN
#
# ...

# %% [markdown]
# # checking for null values

# %%
df.isna().sum()
# Out:
# Segment                  2
# Country                  1
#  Product                 4
#  Discount Band           3
# Units Sold               6
#  Manufacturing Price     1
#  Sale Price              2
#  Gross Sales             3
#  Discounts               1
#   Sales                  1
#  COGS                    3
#  Profit                  1
# Date                     3
# Month Number             0
#  Month Name              2
# Year                     5
# dtype: int64

# %% [markdown]
# # checking for  total null values in a dataset

# %%
print("total number of null values :")
print(df.isna().sum().sum())
# Out:
# total number of null values :
# 38

# %% [markdown]
# # checking for  null values in a dataset using isnull()

# %%
df.isnull()
# Out:
#      Segment  Country   Product    Discount Band   Units Sold  \
# 0      False    False      False            False       False
# 1       True    False      False            False        True
# 2      False    False       True             True        True
# 3      False    False      False            False       False
# 4      False    False      False            False       False
# ..       ...      ...        ...              ...         ...
# 695    False    False       True            False       False
# 696    False    False      False            False       False
# 697     True    False      False            False       False
# 698    False    False       True            False       False
# 699    False    False      False             True       False
#
#       Manufacturing Price    Sale Price    Gross Sales    Discounts   \
# 0                    False         False          False        False
# 1                    False         False          False        False
# ...

# %% [markdown]
# # checking for null values in a heatmap

# %%
sns.heatmap(df.isnull(), yticklabels=False)
# Out:
# <Axes: >

# %% [markdown]
# # Dropping null values in a dataset

# %%
df_dropped=df.dropna(axis=0) 
df_dropped
# Out:
#             Segment                   Country     Product   Discount Band   \
# 0        Government                    Canada   Carretera            None
# 4         Midmarket                    Mexico   Carretera            None
# 6         Midmarket                   Germany     Montana            None
# 12   Small Business                    Mexico     Montana            None
# 14       Enterprise                    Canada     Montana            None
# ..              ...                       ...          ...             ...
# 690      Government  United States of America         VTT            High
# 691       Midmarket                   Germany         VTT            High
# 692      Enterprise                    Canada         VTT            High
# 693      Enterprise                   Germany         VTT            High
# 694      Government                    France         VTT            High
#
#      Units Sold  Manufacturing Price   Sale Price     Gross Sales   \
# ...

# %%
#original dataframe has 700 rows:
    #after dropping null values there are 677 rows

# %% [markdown]
# # checking for null values after dropping null values

# %%
print(df_dropped.isna().sum())
# Out:
# Segment                  0
# Country                  0
#  Product                 0
#  Discount Band           0
# Units Sold               0
#  Manufacturing Price     0
#  Sale Price              0
#  Gross Sales             0
#  Discounts               0
#   Sales                  0
#  COGS                    0
#  Profit                  0
# Date                     0
# Month Number             0
#  Month Name              0
# Year                     0
# dtype: int64

# %%
print(df_dropped.isna().sum().sum())
# Out:
# 0

# %%
sns.heatmap(df_dropped.isnull(), yticklabels=False)
# Out:
# <Axes: >

# %%
df_dropped.isnull()
# Out:
#      Segment  Country   Product    Discount Band   Units Sold  \
# 0      False    False      False            False       False
# 4      False    False      False            False       False
# 6      False    False      False            False       False
# 12     False    False      False            False       False
# 14     False    False      False            False       False
# ..       ...      ...        ...              ...         ...
# 690    False    False      False            False       False
# 691    False    False      False            False       False
# 692    False    False      False            False       False
# 693    False    False      False            False       False
# 694    False    False      False            False       False
#
#       Manufacturing Price    Sale Price    Gross Sales    Discounts   \
# 0                    False         False          False        False
# 4                    False         False          False        False
# ...

# %%
#by seeing this false values we can analyze that all the null values are  dropped and dataset has been clean now!!!
